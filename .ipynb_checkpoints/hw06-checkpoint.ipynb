# %% [markdown]
# # Домашнее задание 6: классификация текстов

# %% [markdown]
# В этом домашнем задании вам предстоит построить классификатор текстов!
#
# Данные мы будем использовать из Kaggle соревнования: https://www.kaggle.com/competitions/nlp-getting-started/data Оттуда надо скачать файл train.csv. На обучающую и тестовую выборки его поделим кодом ниже, менять его не надо!

# %% [markdown]
# Мы будем работать с датасетом постов из твиттера. Нам предстоит решать задачу бинарной классификации - определять содержатся ли в твитте информация о настоящей катастрофе/инциденте или нет.

# %%
import pandas as pd

# %%
data = pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.3, random_state=42)

# %% [markdown]
# ## Задание 1 (0.5 балла)
#
# Выведете на экран информацию о пропусках в данных. Если пропуски присутствуют заполните их пустой строкой.

# %%
train = train.fillna('')
test = test.fillna('')

# %% [markdown]
# ## Задание 2 (1 балл)
# Давайте немного посмотрим на наши данные. Визуализируйте (где явно просят) или выведете информацию о следующем:
#
# 1. Какое распределение классов в обучающей выборке?
# 2. Посмотрите на колонку "keyword" - возьмите 10 наиболее встречающихся значений, постройте ступенчатую диаграмму распределения классов в зависимости от значения keyword, сделайте выводы.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(y=train.target)

# Не буду брать пустые значения
keywords = train['keyword'].value_counts().iloc[1:11].index
yes = []
no = []
for word in keywords:
    counts = train[train.keyword==word].target.value_counts()
    yes.append(counts.get(0, 0))
    no.append(counts.get(1, 0))
    
fig, ax = plt.subplots(figsize=(15,15))

ax.bar(keywords, yes, 0.5, label='0')
ax.bar(keywords, no, 0.5, bottom=yes,
       label='1')

ax.set_ylabel('Количество')
ax.set_title('Распределение классов от первых 10 значений в keyword')
ax.legend()

plt.show()

# %%
# При упоминании слова wreckage речь в 100% случаях шла о катастрофе, что неудивительно, 
# при этом fear и siren употреблялись в подавляющем большинстве случаев не при обсуждении
# настоящей катастрофе и/или инциденте

# %% [markdown]
# ## Задание 3 (0.5 балла)
#
# В этом задании предлагается объединить все три текстовых столбца в один (просто сконкатенировать cтроки) и убрать столбец с индексом.

# %%
train = train.drop(['id'], axis=1)

# %%
train['data'] = train['keyword'] + ' ' + train['location'] + ' ' + train['text']
train = train.drop(['keyword', 'location', 'text'], axis=1)
train
# Out:
#       target                                               data
# 1186       0  bridge%20collapse  Ashes 2015: AustraliaÛªs c...
# 4071       1  hail Carol Stream, Illinois GREAT MICHIGAN TEC...
# 5461       1  police Houston  CNN: Tennessee movie theater s...
# 5787       1  rioting  Still rioting in a couple of hours le...
# 7445       0  wounds Lake Highlands Crack in the path where ...
# ...      ...                                                ...
# 5226       0  obliteration Merica! @Eganator2000 There aren'...
# 5390       0  panic  just had a panic attack bc I don't have...
# 860        0  blood  Omron HEM-712C Automatic Blood Pressure...
# 7603       1    Officials say a quarantine is in place at an...
# 7270       1  whirlwind Stamford & Cork (& Shropshire) I mov...
#
# [5329 rows x 2 columns]

# %%
test['data'] = test['keyword'] + ' ' + test['location'] + ' ' + test['text']
test = test.drop(['keyword', 'location', 'text'], axis=1)
test
# Out:
#         id  target                                               data
# 2644  3796       1  destruction  So you have a new weapon that can...
# 2227  3185       0  deluge  The f$&amp;@ing things I do for #GISHW...
# 5448  7769       1  police UK DT @georgegalloway: RT @Galloway4May...
# 132    191       0  aftershock  Aftershock back to school kick off...
# 6845  9810       0  trauma Montgomery County, MD in response to tr...
# ...    ...     ...                                                ...
# 4307  6115       0  hellfire 570 Vanderbilt; Brooklyn, NY New cock...
# 3375  4833       1  evacuation USA Bend Post Office roofers cut ga...
# 1710  2466       1  collided  Monsoon flooding - Monsoon rains hav...
# 4898  6973       1  massacre Ireland Remember this was a massacre ...
# 6753  9674       1  tornado Asheville, NC I liked a @YouTube video...
#
# [2284 rows x 3 columns]

# %% [markdown]
# ## Задание 4 (0.5 балла)
#
# Далее мы будем пока работать только с train частью.
#
# 1. Предобработайте данные (train часть) с помощью CountVectorizer.
# 2. Какого размера получилась матрица?

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(ngram_range=(1, 1))

# %%
matrix = vectorizer.fit_transform(train['data'])
matrix.shape
# Out:
# (5329, 18455)

# %% [markdown]
# ## Задание 5 (1 балл)
#
# В предыдущем пункте у вас должна была получиться достаточно большая матрица.
# Если вы взгляните на текст, то увидете, что там есть множество специальных символов, ссылок и прочего мусора.
#
# Давайте также посмотрим на словарь, который получился в результате построения CountVectorizer, его можно найти в поле vocabulary_ инстанса этого класса. Давайте напишем функцию, которая печает ответы на следующие вопросы:
#
# 1. Найдите в этом словаре все слова, которые содержат цифры. Сколько таких слов нашлось?
#
# 2. Найдите все слова, которые содержат символы пунктуации. Сколько таких слов нашлось?
#
# 3. Сколько хэштегов (токен начинается на #) и упоминаний (токен начинается на @) осталось в словаре?

# %%
vectorizer.vocabulary_
# Out:
# {'bridge': 2948,
#  '20collapse': 320,
#  'ashes': 1928,
#  '2015': 295,
#  'australia': 2059,
#  'ûªs': 18425,
#  'collapse': 3914,
#  'at': 1977,
#  'trent': 16483,
#  'among': 1628,
#  'worst': 17813,
#  'in': 8314,
#  'history': 7773,
#  'england': 5722,
#  'bundled': 3085,
#  'out': 11995,
#  'for': 6503,
#  '60': 755,
#  'http': 7970,
#  'co': 3861,
#  't5trhjuau0': 15733,
#  'hail': 7420,
#  'carol': 3363,
#  'stream': 15419,
#  'illinois': 8249,
#  'great': 7206,
#  'michigan': 10594,
#  'technique': 15888,
#  'camp': 3261,
#  'b1g': 2147,
#  'thanks': 16013,
#  'to': 16272,
#  'bmurph1019': 2753,
#  'hail_youtsey': 7421,
#  'termn8r13': 15949,
#  'goblue': 7088,
#  'wrestleon': 17848,
#  'oaskgki6qj': 11648,
#  'police': 12634,
#  'houston': 7933,
#  'cnn': 3854,
#  'tennessee': 15932,
#  'movie': 10940,
#  'theater': 16025,
#  'shooting': 14647,
#  'suspect': 15632,
#  'killed': 9246,
#  'by': 3150,
#  'di8elzswnr': 4890,
#  'rioting': 13800,
#  'still': 15357,
# ...

# %%
counts = pd.DataFrame(matrix.toarray(),
                      columns=vectorizer.get_feature_names())

# %%
import re
import string

def get_info(vectorizer: CountVectorizer):
    names = vectorizer.get_feature_names()
    print("Numbers ->", len([name for name in names if bool(re.search(r'\d', name))]))
    print("Punctuation symbols ->", 
          len([name for name in names if bool(re.search(r'[' + string.punctuation + ']', name))]))
    print("Starts with # ->", len([name for name in names if re.match(r'^#', name)]))
    print("Starts with @ ->", len([name for name in names if re.match(r'^@', name)]))

# %%
get_info(vectorizer)
# Out:
# Numbers -> 3812
# Punctuation symbols -> 315
# Starts with # -> 0
# Starts with @ -> 0

# %% [markdown]
# ## Задание 6 (0.5 балла)
#
# Вспомним, что на семинаре по текстам мы узнали, что в nltk есть специальный токенизатор для текстов - TweetTokenizer. Попробуем применить CountVectorizer с этим токенизатором. Ответьте на все вопросы из предыдущего пункта для TweetTokenizer и сравните результаты.

# %%
from nltk.tokenize import TweetTokenizer

tknzr = TweetTokenizer()

tokenized_vectorizer = CountVectorizer(tokenizer=tknzr.tokenize)
tokenized_matrix = tokenized_vectorizer.fit_transform(train['data'])
print(tokenized_matrix.shape)

get_info(tokenized_vectorizer)

# Ну тут лучше токенизация, ибо теперь у нас слова с # и @ не сливаются в 1 и определяются как нормальные
# хештеги и упоминания, а большая часть спец символов выделено в отдельные токены
# Out:
# (5329, 19670)
# Numbers -> 3939
# Punctuation symbols -> 7337
# Starts with # -> 1470
# Starts with @ -> 1679

# %% [markdown]
# ## Задание 7 (2 балла)
#
# В scikit-learn мы можем оценивать процесс подсчета матрицы через CountVectorizer. У CountVectorizer, как и у других наследников \_VectorizerMixin, есть аргумент tokenizer и preprocessor. preprocessor применится в самом начале к каждой строке вашего датасета, tokenizer же должен принять строку и вернуть токены.
# Давайте напишем кастомный токенайзер, которые сделает все, что нам нужно:
#
# 0. Приведет все буквы к нижнему регистру
# 1. Разобьет текст на токены с помощью TweetTokenizer из пакета nltk
# 2. Удалит все токены содержащие не латинские буквы, кроме смайликов (будем считать ими токены содержащие только пунктуацию и, как минимум, одну скобочку) и хэштегов, которые после начальной # содержат только латинские буквы.
# 3. Удалит все токены, которые перечислены в nltk.corpus.stopwords.words('english')
# 4. Проведет стемминг с помощью SnowballStemmer
#
# Продемонстрируйте работу вашей функции на первых десяти текстах в обучающей выборке.

# %%
from nltk import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

def custom_tokenizer(s: str) -> list:
    tt = TweetTokenizer()
    raw = tt.tokenize(s.lower())
    stemmer = SnowballStemmer('english')
    result = [stemmer.stem(token) for token in raw if ((re.match(r'^[a-zA-Z]*$', token)) or (re.match(r'^[' + string.punctuation + ']*$', token) and ')' in token) or ((re.match(r'^[a-zA-Z]*$', token[1:]) and token[0] == '#')))]
    result = [token for token in result if token not in stopwords.words('english')]
    return result

custom_tokenizer(train.data[:10].to_string())
# Out:
# ['bridg',
#  'ash',
#  'australia',
#  'c',
#  'hail',
#  'carol',
#  'stream',
#  'illinoi',
#  'great',
#  'michigan',
#  'tec',
#  'polic',
#  'houston',
#  'cnn',
#  'tennesse',
#  'movi',
#  'theater',
#  'riot',
#  'still',
#  'riot',
#  'coupl',
#  'hour',
#  'le',
#  'wound',
#  'lake',
#  'highland',
#  'crack',
#  'path',
#  'airplan',
#  'somewher',
#  'expert',
#  'bloodi',
#  'isol',
#  'citi',
#  'world',
#  'perth',
#  'came',
#  'burn',
#  'except',
#  'idk',
#  'destroy',
#  'ask',
#  ')',
#  'destroy',
#  'hous',
#  'wound',
#  'maracay',
#  'nirgua',
#  'venezuela',
#  'polic']

# %% [markdown]
# ## Задание 8 (1 балл)
#
# 1. Примените CountVectorizer с реализованным выше токенизатором к обучающим и тестовым выборкам.
# 2. Обучите LogisticRegression на полученных признаках.
# 3. Посчитайте метрику f1-score на тестовых данных.

# %%
custom_vectorizer = CountVectorizer(tokenizer=custom_tokenizer)
custom_matrix = custom_vectorizer.fit_transform(train['data'])
custom_matrix.shape
# Out:
# (5329, 10473)

# %%
get_info(custom_vectorizer)
# Out:
# Numbers -> 0
# Punctuation symbols -> 1329
# Starts with # -> 1323
# Starts with @ -> 0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MaxAbsScaler

bow = custom_vectorizer.fit_transform(train.data)
bow_test = custom_vectorizer.transform(test.data)

# %%
from sklearn.metrics import classification_report

clf = LogisticRegression(max_iter=200, random_state=42)
clf.fit(bow, train.target)

pred = clf.predict(bow_test)
print(classification_report(test.target, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1318
#            1       0.78      0.73      0.75       966
#
#     accuracy                           0.80      2284
#    macro avg       0.80      0.79      0.79      2284
# weighted avg       0.80      0.80      0.80      2284

# %%
from sklearn.metrics import f1_score
pred = clf.predict(bow_test)
f1_score(test.target, pred)
# Out:
# 0.752953813104189

# %% [markdown]
# ## Задание 9 (1 балл)
#
# 1. Повторите 7 задание, но с tf-idf векторизатором. Как изменилось качество?
# 2. Мы можем еще сильнее уменьшить размер нашей матрицы, если отбросим значения df близкие к единице. Скорее всего такие слова не несут много информации о категории, так как встречаются достаточно часто. Ограничьте максимальный df в параметрах TfIdfVectorizer, поставьте верхнюю границу равную 0.9. Как изменился размер матрицы, как изменилось качество?
# 3. Также мы можем уменьшить размер матрицы, удаляя слова со слишком маленьким df. Удалось ли добиться улучшения качества?

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vec = TfidfVectorizer(tokenizer=custom_tokenizer)

tfidf_bow = tfidf_vec.fit_transform(train['data'])
print(tfidf_bow.shape)
tfidf_bow_test = tfidf_vec.transform(test['data'])

tfidf_clf = LogisticRegression(max_iter=200, random_state=42)
tfidf_clf.fit(tfidf_bow, train.target)

tfidf_pred = tfidf_clf.predict(tfidf_bow_test)
print(f1_score(test.target, tfidf_pred))
print(classification_report(test.target, tfidf_pred))
# Out:
# (5329, 10473)
# 0.7440310938367575
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83      1318
#            1       0.80      0.69      0.74       966
#
#     accuracy                           0.80      2284
#    macro avg       0.80      0.78      0.79      2284
# weighted avg       0.80      0.80      0.80      2284

# %%
tfidf_vec = TfidfVectorizer(tokenizer=custom_tokenizer, max_df=0.9)

tfidf_bow = tfidf_vec.fit_transform(train['data'])
print(tfidf_bow.shape)
tfidf_bow_test = tfidf_vec.transform(test['data'])

tfidf_clf = LogisticRegression(max_iter=200, random_state=42)
tfidf_clf.fit(tfidf_bow, train.target)

tfidf_pred = tfidf_clf.predict(tfidf_bow_test)
print(f1_score(test.target, tfidf_pred))
print(classification_report(test.target, tfidf_pred))

# ничего не поменялось, видимо у меня нет настолько часто встречаемых слов
# Out:
# (5329, 10473)
# 0.7440310938367575
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83      1318
#            1       0.80      0.69      0.74       966
#
#     accuracy                           0.80      2284
#    macro avg       0.80      0.78      0.79      2284
# weighted avg       0.80      0.80      0.80      2284

# %%
tfidf_vec = TfidfVectorizer(tokenizer=custom_tokenizer, min_df=2, ngram_range=(1,2))
tfidf_bow = tfidf_vec.fit_transform(train['data'])
print(tfidf_bow.shape)
tfidf_bow_test = tfidf_vec.transform(test['data'])

tfidf_clf = LogisticRegression(max_iter=200, random_state=42)
tfidf_clf.fit(tfidf_bow, train.target)

tfidf_pred = tfidf_clf.predict(tfidf_bow_test)
print(f1_score(test.target, tfidf_pred))
print(classification_report(test.target, tfidf_pred))

# Чуть лучше стало, но неощутимо
# Out:
# (5329, 8943)
# 0.7462520821765685
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.83      1318
#            1       0.80      0.70      0.75       966
#
#     accuracy                           0.80      2284
#    macro avg       0.80      0.79      0.79      2284
# weighted avg       0.80      0.80      0.80      2284

# %% [markdown]
# ## Задание 10 (1 балл)
#
# Еще один популяпный трюк, который позволит уменьшить количество признаков называется hashing trick. Его суть в том, то мы случайно группируем признаки ииии  ..... складываем их! А потом удаляем исходные признаки. В итоге все наши признаки это просто суммы исходных. Звучит странно, но это отлично работает. Давайте проверим этот трюк в нашем сеттинге.
# Также при таком подходе вам не нужно хранить словарь token->index, что тоже иногда полезно.
#
# 1. Повторите задание 7 с HashingVectorizer, укажите количество фичей равное 5000.
# 2. Какой из подходов показал самый высокий результат?

# %%
from sklearn.feature_extraction.text import HashingVectorizer

hash_vec = HashingVectorizer(tokenizer=custom_tokenizer, n_features=5000)

hash_bow = hash_vec.fit_transform(train['data'])
print(hash_bow.shape)
hash_bow_test = hash_vec.transform(test['data'])

hash_clf = LogisticRegression(max_iter=200, random_state=42)
hash_clf.fit(hash_bow, train.target)

hash_pred = hash_clf.predict(hash_bow_test)
print(f1_score(test.target, hash_pred))
print(classification_report(test.target, hash_pred))

# Самый первый = самый лучший
# Out:
# /home/genuis/anaconda3/lib/python3.8/site-packages/sklearn/feature_extraction/text.py:489: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn("The parameter 'token_pattern' will not be used"
# (5329, 5000)
# 0.7201783723522853
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82      1318
#            1       0.78      0.67      0.72       966
#
#     accuracy                           0.78      2284
#    macro avg       0.78      0.77      0.77      2284
# weighted avg       0.78      0.78      0.78      2284

# %% [markdown]
# ## Задание 11 (1 балл)
#
# В этом задании нужно добиться f1 меры хотя в 0.75 на тестовых данных.

# %%
bow = custom_vectorizer.fit_transform(train.data)
bow_test = custom_vectorizer.transform(test.data)

clf = LogisticRegression(max_iter=200, random_state=42)
clf.fit(bow, train.target)

pred = clf.predict(bow_test)
print(classification_report(test.target, pred))
print(f1_score(test.target, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83      1318
#            1       0.78      0.73      0.75       966
#
#     accuracy                           0.80      2284
#    macro avg       0.80      0.79      0.79      2284
# weighted avg       0.80      0.80      0.80      2284
#
# 0.752953813104189
